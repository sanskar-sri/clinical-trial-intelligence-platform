# %% [markdown]
# MATERLISED VIEW

# %%
# Create a Bronze schema
spark.sql("CREATE SCHEMA IF NOT EXISTS bronze COMMENT 'Bronze layer: raw ingested data'")
print("Bronze schema created successfully.")

# %%
source_path = "s3://clinical-trial-intelligence-platform-sk/Landing/EDC/subjects/"

df = (
    spark.read
    .option("header", "true")
    .option("inferSchema", "true")
    .csv(source_path)
)

display(df.limit(10))
